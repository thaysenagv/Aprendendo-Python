# %%
from random import randint

capacidade_maxima_balde = 1000


balde = 0

while balde <= capacidade_maxima_balde:
  volume_copo = randint(95,100)

  print(f'O copo foi enchido com {volume_copo} mls')

  balde+= volume_copo

  print(f'O volume do balde é de {balde}mls\n')

print(f'O volume do balde ultrapassou a capacidade máxima de{capacidade_maxima_balde} mls e está com {balde} mls ')
# Out:
# O copo foi enchido com 95 mls
# O volume do balde é de 95mls
#
# O copo foi enchido com 99 mls
# O volume do balde é de 194mls
#
# O copo foi enchido com 97 mls
# O volume do balde é de 291mls
#
# O copo foi enchido com 100 mls
# O volume do balde é de 391mls
#
# O copo foi enchido com 99 mls
# O volume do balde é de 490mls
#
# O copo foi enchido com 98 mls
# O volume do balde é de 588mls
#
# O copo foi enchido com 100 mls
# O volume do balde é de 688mls
#
# O copo foi enchido com 97 mls
# O volume do balde é de 785mls
#
# O copo foi enchido com 99 mls
# O volume do balde é de 884mls
#
# O copo foi enchido com 98 mls
# O volume do balde é de 982mls
#
# O copo foi enchido com 99 mls
# O volume do balde é de 1081mls
#
# O volume do balde ultrapassou a capacidade máxima de1000 mls e está com 1081 mls
